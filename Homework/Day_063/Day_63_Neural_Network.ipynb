# %% [markdown]
# # sigmoid 函數圖形
# * 講義中的 sigmoid 程式對照

# %%
import matplotlib.pylab as plt 
import numpy as np 
# %matplotlib inline  
x = np.arange(-8, 8, 0.1) 
f = 1 / (1 + np.exp(-x)) 
plt.plot(x, f) 
plt.xlabel('x') 
plt.ylabel('f(x)') 
plt.show()

# %% [markdown]
# # 作業
# * 請參閱範例中的 hidden Layer 寫法, 完成 output Layer 的程式
